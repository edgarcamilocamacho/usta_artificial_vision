# %% [markdown]
# # Este es un título

# %% [markdown]
# Este es un texto

# %% [markdown]
# $X=log_{10}$

# %%
x = 10

# %%
print(x)
# Out:
# 10

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 10, 50)
y = np.sin(x)

# %%
x.shape
# Out:
# (50,)

# %%
plt.plot(x, y)

# %%
from imageio import imread

# %%
img = imread('./data/img/cat1.jpg')

# %%
img.shape
# Out:
# (400, 248, 3)

# %%
plt.imshow(img)

# %%
plt.imshow(img[:,0:125,:])

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
img2 = img//2

# %%
img2.dtype
# Out:
# dtype('uint8')

# %%
plt.imshow(img2)

# %%
img.shape
# Out:
# (400, 248, 3)

# %%
img2.shape
# Out:
# (400, 248, 3)

# %%
imgR = np.uint8(img * [1.0, 0.0, 0.0])

# %%
imgR.shape
# Out:
# (400, 248, 3)

# %%
plt.imshow(imgR)

# %%
img0 = img[:,:,0]
img0.shape
# Out:
# (400, 248)

# %%
plt.imshow(img0, cmap='gray')
